# %%
pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 26.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 22.9 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 24.0 -> 26.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_csv("/Users/maraeckart/dev/hslu/fs26/MLOPS/project/I.BA_MLOPS/data/raw/raw_guardian_news_2026-04-29.csv")

df.head()
df.info()
df["category"].value_counts()

df = df.drop_duplicates(subset=["headline", "url"])
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   headline             235 non-null    str
#  1   description          235 non-null    str
#  2   url                  235 non-null    str
#  3   published_at         235 non-null    str
#  4   source_name          235 non-null    str
#  5   category             235 non-null    str
#  6   ingestion_timestamp  235 non-null    str
# dtypes: str(7)
# memory usage: 13.0 KB
